# %%
import requests
import json

api_url = "https://api-web.nhle.com"

response = requests.get(api_url + "/v1/club-stats/BOS/now")

response.json()
# Out:
# {'season': '20232024',
#  'gameType': 2,
#  'skaters': [{'playerId': 8473419,
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20232024/BOS/8473419.png',
#    'firstName': {'default': 'Brad'},
#    'lastName': {'default': 'Marchand'},
#    'positionCode': 'L',
#    'gamesPlayed': 51,
#    'goals': 25,
#    'assists': 23,
#    'points': 48,
#    'plusMinus': 9,
#    'penaltyMinutes': 55,
#    'powerPlayGoals': 7,
#    'shorthandedGoals': 2,
#    'gameWinningGoals': 6,
#    'overtimeGoals': 2,
#    'shots': 134,
#    'shootingPctg': 0.186567,
#    'avgTimeOnIcePerGame': 1167.3922,
#    'avgShiftsPerGame': 24.3529,
#    'faceoffWinPctg': 0.44186},
#   {'playerId': 8473473,
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20232024/BOS/8473473.png',
#    'firstName': {'default': 'Milan'},
#    'lastName': {'default': 'Lucic'},
#    'positionCode': 'L',
#    'gamesPlayed': 4,
#    'goals': 0,
#    'assists': 2,
#    'points': 2,
#    'plusMinus': -1,
#    'penaltyMinutes': 2,
# ...
