# %%
import requests
import json

api_url = "https://api-web.nhle.com"

response = requests.get("https://api-web.nhle.com/v1/score/2023-11-10")
response.json()
# Out:
# {'prevDate': '2023-11-09',
#  'currentDate': '2023-11-10',
#  'nextDate': '2023-11-11',
#  'gameWeek': [{'date': '2023-11-07', 'dayAbbrev': 'TUE', 'numberOfGames': 10},
#   {'date': '2023-11-08', 'dayAbbrev': 'WED', 'numberOfGames': 3},
#   {'date': '2023-11-09', 'dayAbbrev': 'THU', 'numberOfGames': 11},
#   {'date': '2023-11-10', 'dayAbbrev': 'FRI', 'numberOfGames': 6},
#   {'date': '2023-11-11', 'dayAbbrev': 'SAT', 'numberOfGames': 12},
#   {'date': '2023-11-12', 'dayAbbrev': 'SUN', 'numberOfGames': 5},
#   {'date': '2023-11-13', 'dayAbbrev': 'MON', 'numberOfGames': 2}],
#  'oddsPartners': [{'partnerId': 2,
#    'country': 'SE',
#    'name': 'Unibet',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/unibet.svg',
#    'siteUrl': 'https://www.unibet.se/betting/sports/filter/ice_hockey/nhl/all/matches',
#    'bgColor': '#14805E',
#    'textColor': '#FFFFFF',
#    'accentColor': '#3AAA35'},
#   {'partnerId': 3,
#    'country': 'CZ',
#    'name': 'Tipsport',
# ...
