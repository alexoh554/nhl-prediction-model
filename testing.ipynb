# %%
import requests
import json

api_url = "https://api-web.nhle.com"

club_stats = requests.get(f"{api_url}/v1/club-stats/BOS/20222023/2").json()
club_stats
# Out:
# {'season': '20222023',
#  'gameType': 2,
#  'skaters': [{'playerId': 8470638,
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20222023/BOS/8470638.png',
#    'firstName': {'default': 'Patrice'},
#    'lastName': {'default': 'Bergeron'},
#    'positionCode': 'C',
#    'gamesPlayed': 78,
#    'goals': 27,
#    'assists': 31,
#    'points': 58,
#    'plusMinus': 35,
#    'penaltyMinutes': 22,
#    'powerPlayGoals': 9,
#    'shorthandedGoals': 2,
#    'gameWinningGoals': 7,
#    'overtimeGoals': 0,
#    'shots': 249,
#    'shootingPctg': 0.108434,
#    'avgTimeOnIcePerGame': 1043.5,
#    'avgShiftsPerGame': 25.1667,
#    'faceoffWinPctg': 0.611372},
#   {'playerId': 8471276,
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20222023/BOS/8471276.png',
#    'firstName': {'default': 'David'},
#    'lastName': {'default': 'Krejci', 'cs': 'Krejčí', 'sk': 'Krejčí'},
#    'positionCode': 'C',
#    'gamesPlayed': 70,
#    'goals': 16,
#    'assists': 40,
#    'points': 56,
# ...
